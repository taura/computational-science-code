# %% [markdown]
# # 練習問題: 2つの数の平均を求める
#
# ## 目標
#
# C++ / Fortran のプログラムをコンパイルして実行する流れを確認し,
# 変数を使った簡単な算術式を1つ書けるようになる.
#
# ## 課題
#
# `average.cpp` (または `average.f90`) は, 2つの数 `a` と `b` の平均を求めて表示するプログラムである.
# ただし, 平均を計算する1行が `TODO` として空欄になっている.
#
# コメント `TODO` の指示に従って **平均を計算する式を1文だけ** 書き加え,
# 正しい平均が表示されるようにせよ.
#
# - C++: `double m = ...;` の右辺を埋める.
# - Fortran: `m = ...` の右辺を埋める.
#
# それ以外のコードを変更する必要はない.
#
# ヒント: 整数同士の割り算は小数部が切り捨てられる. ここでは `a`, `b` は浮動小数点なので問題ないが,
# `2` で割ることを忘れずに.
#
# ## コンパイルと実行
#
# ```
# # C++
# nvc++ -fast average.cpp -o average.exe
#
# # Fortran
# nvfortran -fast average.f90 -o average.exe
# ```
#
# ```
# ./average.exe
# ```
#
# ## 期待される結果
#
# `a = 3.0`, `b = 4.0` の平均が表示される.
#
# ```
# average of 3.000000 and 4.000000 is 3.500000
# ```

# %% [markdown]
# # 1. AIチューター

# %%
import heytutor

# %% [markdown]
# ## 1-1. 一般的な質問
# ```
# %%hey
#
# C++の関数の書き方は?
# ```
#
# ## 1-2. この問題に関するヒント
# ```
# %%hey
#
# この問題に関するヒントを教えて
# ```
#
# ## 1-3. いくつかの変数
# * `{file:FILENAME}` : _FILENAME_ の中身
# * `{bash[-1]}` : 最後に実行した `%%bash_` セルの出力, `{bash[-2]}` = その前の出力, etc.
# * `{problem}` : `%%hey problem_file=foo.md` で指定したファイルの中身
# * `{answer}` : `%%hey answer_file=foo.cpp` で指定したファイルの中身
#
# ## 1-4. 困ったときのヘルプ
# ```
# %%hey answer_file=foo.cpp
#
# コンパイル時に以下のエラーが出た。何が間違い?
#
# プログラム:
# {answer}
#
# エラーメッセージ:
# {bash[-1]}
#
# ```
#
# ## 1-5. フィードバック
# * 答えが出た後も、無駄なところや、より良いやり方がないかを聞くと良い。
#
# ```
# %%hey problem_file=foo.md answer_file=foo.cpp
#
# フィードバックを下さい。
#
# 問題:
# {problem}
#
# 私の答:
# {answer}
# ```

# %% [markdown]
# # 2. ジョブ投入ツール

# %%
import wisteria_submit

# %% [markdown]
# # 3. C++ ベースコード

# %%
import heytutor

# %%
# %%writefile_ average.cpp
# #include <cstdio>
#
# int main() {
#   double a = 3.0;
#   double b = 4.0;
#   /* TODO: a と b の平均を計算して m に代入せよ (右辺を埋める). */
#   double m = ;
#   printf("average of %f and %f is %f\n", a, b, m);
#   return 0;
# }

# %% [markdown]
# ## 3-1. コンパイル

# %%
# %%bash_
# PATH=/work/opt/local/x86_64/cores/nvidia/23.3/Linux_x86_64/23.3/compilers/bin:/opt/FJSVxtclanga/tcsds-1.2.41/bin:$PATH
# nvc++ -fast $average.cpp -o $average_cpp.exe

# %% [markdown]
# ## 3-2. Run

# %%
# %%bash_
# ./$average_cpp.exe

# %% [markdown]
# ## 3-3. 質問/フィードバック

# %%
# %%hey problem_file=problem.md answer_file=average.cpp
#
# 問題:
# {problem}
#
# 私の答:
# {answer}
#
# 私の答に対するフィードバックをください。

# %% [markdown]
# # 4. Fortran ベースコード

# %%
import heytutor

# %%
# %%writefile_ average.f90
# program average
#   real(8) :: a, b, m
#   a = 3.0d0
#   b = 4.0d0
#   ! TODO: a と b の平均を計算して m に代入せよ (右辺を埋める).
#   m =
#   print "(a,f0.6,a,f0.6,a,f0.6)", "average of ", a, " and ", b, " is ", m
# end program average

# %% [markdown]
# ## 4-1. コンパイル

# %%
# %%bash_
# PATH=/work/opt/local/x86_64/cores/nvidia/23.3/Linux_x86_64/23.3/compilers/bin:/opt/FJSVxtclanga/tcsds-1.2.41/bin:$PATH
# nvfortran -fast $average.f90 -o $average_f90.exe

# %% [markdown]
# ## 4-2. Run

# %%
# %%bash_
# ./$average_f90.exe

# %% [markdown]
# ## 4-3. 質問/フィードバック

# %%
# %%hey problem_file=problem.md answer_file=average.f90
#
# 問題:
# {problem}
#
# 私の答:
# {answer}
#
# 私の答に対するフィードバックをください。
